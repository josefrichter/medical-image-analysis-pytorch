# %%
import nibabel as nib
from matplotlib import pyplot as plt
from matplotlib.colors import NoNorm
import numpy as np
# %matplotlib notebook
# %matplotlib inline

t1image = nib.load('./small/t1/IXI176-HH-1604-T1_fcm.nii.gz')
t2image = nib.load('./small/t2/IXI176-HH-1604-T2_reg_fcm.nii.gz')


t1image_data = t1image.get_fdata()
t2image_data = t2image.get_fdata()


sliceNumber  = 40

t1slice = t1image_data[:,:,sliceNumber]
t2slice = t2image_data[:,:,sliceNumber]

print(t1image_data.shape)
print(t2image_data.shape)
print(f'T1 min={np.amin(t1slice)} max={np.amax(t1slice)}')
print(f'T2 min={np.amin(t2slice)} max={np.amax(t2slice)}')


plt.subplot(1,2,1)
plt.imshow(np.rot90(t1slice), interpolation='nearest', cmap='gray')
plt.subplot(1,2,2)
plt.imshow(np.rot90(t2slice), interpolation='nearest', cmap='gray')

plt.show()
# Out:
# (120, 120, 90)
# (120, 120, 90)
# T1 min=-0.011743617244064808 max=1.6446267366409302
# T2 min=-0.0017424682155251503 max=4.622004985809326
